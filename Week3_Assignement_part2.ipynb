# %% [markdown]
# # Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# <p style="font-family: Arial; font-size:1.4em;color:Orange;"> First part of the assignement </p>

# %% [markdown]
# #### The code below comprises the instalation of libraries, web scraping, transformation to pandas dataframe and data cleaning

# %%
import pandas
import requests
from bs4 import BeautifulSoup
website_text = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(website_text,'xml')

table = soup.find('table',{'class':'wikitable sortable'})
table_rows = table.find_all('tr')

data = []
for row in table_rows:
    data.append([t.text.strip() for t in row.find_all('td')])

df = pandas.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighbourhood'])
df = df[~df['PostalCode'].isnull()]  # to filter out bad rows

df.head(180)
# Out:
#     PostalCode           Borough  \
# 1          M1A      Not assigned
# 2          M2A      Not assigned
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# ..         ...               ...
# 176        M5Z      Not assigned
# 177        M6Z      Not assigned
# 178        M7Z      Not assigned
# 179        M8Z         Etobicoke
# 180        M9Z      Not assigned
#
#                                          Neighbourhood
# 1                                         Not assigned
# 2                                         Not assigned
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                            Regent Park, Harbourfront
# ..                                                 ...
# 176                                       Not assigned
# 177                                       Not assigned
# 178                                       Not assigned
# ...

# %% [markdown]
# #### Data cleaning

# %%
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
# Drop Rows where borough = Not assigned
df = df[df.Borough != 'Not assigned']

df.head(180)
# Out:
#     PostalCode           Borough  \
# 3          M3A        North York
# 4          M4A        North York
# 5          M5A  Downtown Toronto
# 6          M6A        North York
# 7          M7A  Downtown Toronto
# ..         ...               ...
# 161        M8X         Etobicoke
# 166        M4Y  Downtown Toronto
# 169        M7Y      East Toronto
# 170        M8Y         Etobicoke
# 179        M8Z         Etobicoke
#
#                                          Neighbourhood
# 3                                            Parkwoods
# 4                                     Victoria Village
# 5                            Regent Park, Harbourfront
# 6                     Lawrence Manor, Lawrence Heights
# 7          Queen's Park, Ontario Provincial Government
# ..                                                 ...
# 161      The Kingsway, Montgomery Road, Old Mill North
# 166                               Church and Wellesley
# 169  Business reply mail Processing Centre, South C...
# ...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# <p style="font-family: Arial; font-size:1.4em;color:Orange;"> Second part of the assignement </p>

# %% [markdown]
# #### The code below adds latitude and the longitude coordinates of each neighborhood

# %%
lat_lon = pd.read_csv('https://cocl.us/Geospatial_data')
lat_lon.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# #### The code below rename the "Postal Code" field of Geospatial_data to be in line with the Toronto Nighbourhood table and then join them in one dataframe

# %%
lat_lon.rename(columns={'Postal Code':'PostalCode'},inplace=True)

# %%
#lat_lon.rename(columns={'Postal Code':'Postcode'},inplace=True)
df2 = pd.merge(df,lat_lon,on='PostalCode')
df2
# Out:
#     PostalCode           Borough  \
# 0          M3A        North York
# 1          M4A        North York
# 2          M5A  Downtown Toronto
# 3          M6A        North York
# 4          M7A  Downtown Toronto
# ..         ...               ...
# 98         M8X         Etobicoke
# 99         M4Y  Downtown Toronto
# 100        M7Y      East Toronto
# 101        M8Y         Etobicoke
# 102        M8Z         Etobicoke
#
#                                          Neighbourhood   Latitude  Longitude
# 0                                            Parkwoods  43.753259 -79.329656
# 1                                     Victoria Village  43.725882 -79.315572
# 2                            Regent Park, Harbourfront  43.654260 -79.360636
# 3                     Lawrence Manor, Lawrence Heights  43.718518 -79.464763
# 4          Queen's Park, Ontario Provincial Government  43.662301 -79.389494
# ..                                                 ...        ...        ...
# ...
